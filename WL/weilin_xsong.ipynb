# %%
def getPlateNum(fn, s0='Plate'):
    p0 = fn.find(s0)    
    return fn[p0:len(fn)]

def generateWellName():
    list1 = map(chr, range(65, 73))
    list2 = range(1,13,1)
    list2 = map(str, list2)  
    well_name = []
    for l in list1:
        for n in list2:
            well_name.append(l+n)
    return well_name

def getValuesfromPlate(fn, values_in_plate):
    print fn
    import numpy as np
    import re  
    import os
    f = open(fn, 'r')     
    for line in f:        
        line_content = re.split(r'\t+',line)
        name = line_content[0]
        if name in well_names:            
            od = float(line_content[1])
            try: 
                fluo1 = float(line_content[2])
            except:
                fluo1 = -1         
            try:
                fluo2 = float(line_content[3])
            except:
                fluo2 = -1
            if name not in values_in_plate.keys():
                values_in_plate[name]= []
            values_in_plate[name].append([od,fluo1,fluo2])
    f.close()

# %%
import csv
def alphanum_key(s):
    import re
    convert = lambda text: int(text) if text.isdigit() else text 
    return [convert(c) for c in re.split('([0-9]+)', s)]


def plateToFile(values_in_plate, plate_name):
    output_folder = os.path.join(root,plate_name)
    os.mkdir(output_folder)
    
    keys = values_in_plate.keys()
    keys.sort(key=alphanum_key)        
    value_matrix = dict()
    out_names = ['OD','GFP_50','GFP_100','GFP_extra']

    head_line = ['']

    for well in keys:
        head_line.append(well)
        values = values_in_plate[well]
        npvalues = np.asarray(values)
        [r,c] = npvalues.shape
        for col in range(c):        
            v_m = npvalues[:,col]
            v_m = v_m.reshape(-1,1)
            if col not in value_matrix.keys():
                value_matrix[col] = v_m
            else:
                value_matrix[col] = np.concatenate((value_matrix[col], v_m), axis = 1)

    for col in value_matrix.keys():
        out_name = out_names[int(col)]
        fn = os.path.join(output_folder,plate_name+'_'+str(out_name)+'.csv')
        print "create ", fn    
        with open(fn, mode='w') as data_file:
            data_writer = csv.writer(data_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)        
            data_writer.writerow(head_line)
            mat = value_matrix[col]
            [r, c] = mat.shape
            for i in range(r):
                a = [i]
                a.extend(mat[i,:].tolist())
                data_writer.writerow(a)

# %%
import csv
import os
import numpy as np

folder = 'asc'

extension = '.asc'
content = 'Plate'
fns =[]
num_plate = []

well_names = generateWellName()

for root, dirs, files in os.walk(folder):
    for fn in files:
        if fn.endswith(extension) and content in fn:
            pth = os.path.join(root, fn)
            fns.append(os.path.abspath(pth))
            if getPlateNum(fn, content) not in num_plate:
                num_plate.append(getPlateNum(fn, content))

fns = sorted(fns)

files_order_by_plate = dict()
for val in num_plate:
    my_list = filter(lambda x: val in x, fns)
    files_order_by_plate[val] = my_list
    
plates_reader = dict()
for plate in sorted(files_order_by_plate.keys()):
    list_fns_plate = files_order_by_plate[plate]
    values_in_plate = dict()
    print "Process ",plate
    for fn in list_fns_plate:
        #print plate
        getValuesfromPlate(fn, values_in_plate)
    plates_reader[plate] = values_in_plate 
    
    # to be changed according to the table
    plate_name = plate[0:plate.find('.')] 
    #od_file = os.pe
    plateToFile(values_in_plate, plate_name)
# Out:
# Process  Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-204_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-215_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-225_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-235_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-245_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-255_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-265_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-010_Plate1.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-020_Plate1.asc
# create  asc/Plate1/Plate1_OD.csv
# create  asc/Plate1/Plate1_GFP_50.csv
# create  asc/Plate1/Plate1_GFP_song0.csv
# Process  Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-213_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-214_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-224_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-234_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-244_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-254_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-264_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-009_Plate10.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-019_Plate10.asc
# create  asc/Plate10/Plate10_OD.csv
# create  asc/Plate10/Plate10_GFP_50.csv
# create  asc/Plate10/Plate10_GFP_song0.csv
# Process  Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-205_Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-216_Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-226_Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-236_Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-246_Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-256_Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-001_Plate2.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-011_Plate2.asc
# create  asc/Plate2/Plate2_OD.csv
# create  asc/Plate2/Plate2_GFP_50.csv
# create  asc/Plate2/Plate2_GFP_song0.csv
# Process  Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-206_Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-217_Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-227_Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-237_Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-247_Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-257_Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-002_Plate3.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-012_Plate3.asc
# create  asc/Plate3/Plate3_OD.csv
# create  asc/Plate3/Plate3_GFP_50.csv
# create  asc/Plate3/Plate3_GFP_song0.csv
# Process  Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-207_Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-218_Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-228_Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-238_Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-248_Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-258_Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-003_Plate4.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-013_Plate4.asc
# create  asc/Plate4/Plate4_OD.csv
# create  asc/Plate4/Plate4_GFP_50.csv
# create  asc/Plate4/Plate4_GFP_song0.csv
# Process  Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-208_Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-219_Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-229_Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-239_Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-249_Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-259_Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-004_Plate5.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-014_Plate5.asc
# create  asc/Plate5/Plate5_OD.csv
# create  asc/Plate5/Plate5_GFP_50.csv
# create  asc/Plate5/Plate5_GFP_song0.csv
# Process  Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-209_Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-220_Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-230_Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-240_Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-250_Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-260_Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-005_Plate6.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-015_Plate6.asc
# create  asc/Plate6/Plate6_OD.csv
# create  asc/Plate6/Plate6_GFP_50.csv
# create  asc/Plate6/Plate6_GFP_song0.csv
# Process  Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-210_Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-221_Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-231_Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-241_Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-251_Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-261_Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-006_Plate7.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-016_Plate7.asc
# create  asc/Plate7/Plate7_OD.csv
# create  asc/Plate7/Plate7_GFP_50.csv
# create  asc/Plate7/Plate7_GFP_song0.csv
# Process  Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-211_Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-222_Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-232_Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-242_Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-252_Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-262_Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-007_Plate8.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-017_Plate8.asc
# create  asc/Plate8/Plate8_OD.csv
# create  asc/Plate8/Plate8_GFP_50.csv
# create  asc/Plate8/Plate8_GFP_song0.csv
# Process  Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-212_Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-223_Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-233_Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-243_Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-253_Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181031-263_Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-008_Plate9.asc
# /home/xsong/Desktop/weilin/WL/asc/181101-018_Plate9.asc
# create  asc/Plate9/Plate9_OD.csv
# create  asc/Plate9/Plate9_GFP_50.csv
# create  asc/Plate9/Plate9_GFP_song0.csv
